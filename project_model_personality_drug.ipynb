# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("drug_consumption.csv", 
                  names=["Age", "Gender", "Education", "Country", "Ethnicity", "Nscore", "Escore", "Oscore", "Ascore", "Cscore", "Impulsive", "SS", "Alcohol", "Amphet", "Amyl", "Benzos", "Caff", "Cannabis", "Choc", "Coke", "Crack", "Ecstasy", "Heroin", "Ketamine", "Legalh", "LSD", "Meth", "Mushrooms", "Nicotine", "Semer", "VSA"])

# %%
#remove instances where individuals reported having taken Semer, a fictional drug
df = df[df.Semer == 'CL0']

# %%
arr = ["Alcohol", "Amphet", "Amyl", "Benzos", "Caff", "Cannabis", "Choc", "Coke", "Crack", "Ecstasy", "Heroin", "Ketamine", "Legalh", "LSD", "Meth", "Mushrooms", "Nicotine", "Semer", "VSA"]
# Collapse values into never used = 0 and have used = 1, include drug name for label when OHE
for i in range(0,18):
    df[arr[i]].replace({"CL0": 0, "CL1": 1, "CL2": 1, "CL3": 1, "CL4": 1, "CL5": 1, "CL6": 1}, inplace=True)
# Out:
# C:\Users\lehuu\AppData\Local\Temp\ipykernel_21528\1530635827.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[arr[i]].replace({"CL0": 0, "CL1": 1, "CL2": 1, "CL3": 1, "CL4": 1, "CL5": 1, "CL6": 1}, inplace=True)
# C:\Users\lehuu\AppData\Local\Temp\ipykernel_21528\1530635827.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[arr[i]].replace({"CL0": 0, "CL1": 1, "CL2": 1, "CL3": 1, "CL4": 1, "CL5": 1, "CL6": 1}, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, MinMaxScaler
from enum import IntEnum

X = df[["Nscore", "Escore", "Oscore", "Ascore", "Cscore", "Impulsive", "SS"]]
y_cols = ["Alcohol", "Amphet", "Cannabis", "Coke", "Ecstasy", "LSD", "Meth", "Mushrooms"]
y_enum = IntEnum("cols", y_cols, start = 0)
y = df[["Alcohol", "Amphet", "Cannabis", "Coke", "Ecstasy", "LSD", "Meth", "Mushrooms"]]

# def one_hot_encoding(df, col):
#     # one-hot encoding to represent classes
#     myData_encoder = LabelEncoder()
#     myData_encoded =  myData_encoder.fit_transform(df[col]) 

#     # binary encode
#     onehot_encoder = OneHotEncoder(sparse=False) # disable sparse return type

#     # reshape the array
#     myData_encoded = myData_encoded.reshape(len(myData_encoded), 1) 
#     onehot_encoded = onehot_encoder.fit_transform(myData_encoded) 
#     #print(onehot_encoded)
#     # convert ndarrary of encodings to dataframe using myData_encoder.classes_ as column names
#     return(pd.DataFrame(onehot_encoded, columns = myData_encoder.classes_))

# for col_name in y_cols:
#     #one-hot encode every y_col
#     y[y_enum[col_name].value] = one_hot_encoding(df, col_name)

# %% [markdown]
# ## GRID SEARCH:

# %%
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import mean_squared_error, precision_score, recall_score
from sklearn.model_selection import GridSearchCV

model_params = [None] * len(y_cols) #list of model parameters in y_cols order

#pass inputs X and target y
#returns dictionary of best params for hidden_layer_sizes and learning_rate_init
def search(X, y):
    X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=1, test_size=0.2)

    clf = MLPClassifier(hidden_layer_sizes=(32, 24, 12), learning_rate_init = 0.1, activation="logistic",solver = 'sgd', max_iter = 1000, random_state=1)

    # Grid Search
    max_iterations = [10, 50, 100, 300, 600, 1000]
    hidden_layer_sizes = [(24, 12), (32, 16), (64, 32), (32, 16, 8), (64, 32, 16)]
    learning_rate_init = [0.1, 0.2, 0.3, 0.4]
    activation = ["logistic", "relu", "tanh"]
    param_grid = dict(max_iter=max_iterations, hidden_layer_sizes=hidden_layer_sizes, learning_rate_init=learning_rate_init, activation=activation)
    grid = GridSearchCV(estimator=clf, param_grid=param_grid, n_jobs=-1, cv=3)
    grid_result = grid.fit(X_train, y_train)
    
    # summarize results - this code was taken from a lecture example
    print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))

    means = grid_result.cv_results_['mean_test_score']
    stds = grid_result.cv_results_['std_test_score']
    params = grid_result.cv_results_['params']
    for mean, stdev, param in zip(means, stds, params):
        print("%f (%f) with: %r" % (mean, stdev, param))
    
    return grid_result.best_params_

for drug in y_cols:
    print(drug)
    model_params[y_enum[drug].value] = search(X, y[drug])
# Out:
# Alcohol
# C:\Users\lehuu\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Best: 0.981348 using {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.3, 'max_iter': 100}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 100}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 300}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 600}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 100}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 300}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 600}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.3, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.3, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.3, 'max_iter': 100}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.3, 'max_iter': 300}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.3, 'max_iter': 600}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.3, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.4, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.4, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.4, 'max_iter': 100}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.4, 'max_iter': 300}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.4, 'max_iter': 600}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.4, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.1, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.1, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.1, 'max_iter': 100}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.1, 'max_iter': 300}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.1, 'max_iter': 600}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.1, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.2, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.2, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.2, 'max_iter': 100}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.2, 'max_iter': 300}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.2, 'max_iter': 600}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.2, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.3, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.3, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.3, 'max_iter': 100}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.3, 'max_iter': 300}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.3, 'max_iter': 600}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.3, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.4, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.4, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.4, 'max_iter': 100}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.4, 'max_iter': 300}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.4, 'max_iter': 600}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.4, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.1, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.1, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.1, 'max_iter': 100}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.1, 'max_iter': 300}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.1, 'max_iter': 600}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.1, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.2, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.2, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.2, 'max_iter': 100}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.2, 'max_iter': 300}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.2, 'max_iter': 600}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.2, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.3, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.3, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.3, 'max_iter': 100}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.3, 'max_iter': 300}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.3, 'max_iter': 600}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.3, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.4, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.4, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.4, 'max_iter': 100}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.4, 'max_iter': 300}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.4, 'max_iter': 600}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.4, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.1, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.1, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.1, 'max_iter': 100}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.1, 'max_iter': 300}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.1, 'max_iter': 600}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.1, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.2, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.2, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.2, 'max_iter': 100}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.2, 'max_iter': 300}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.2, 'max_iter': 600}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.2, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.3, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.3, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.3, 'max_iter': 100}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.3, 'max_iter': 300}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.3, 'max_iter': 600}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.3, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.4, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.4, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.4, 'max_iter': 100}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.4, 'max_iter': 300}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.4, 'max_iter': 600}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.4, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.1, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.1, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.1, 'max_iter': 100}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.1, 'max_iter': 300}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.1, 'max_iter': 600}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.1, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.2, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.2, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.2, 'max_iter': 100}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.2, 'max_iter': 300}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.2, 'max_iter': 600}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.2, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.3, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.3, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.3, 'max_iter': 100}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.3, 'max_iter': 300}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.3, 'max_iter': 600}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.3, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.4, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.4, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.4, 'max_iter': 100}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.4, 'max_iter': 300}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.4, 'max_iter': 600}
# 0.981347 (0.000924) with: {'activation': 'logistic', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.4, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 100}
# 0.980016 (0.002806) with: {'activation': 'relu', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 300}
# 0.979351 (0.003747) with: {'activation': 'relu', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 600}
# 0.979351 (0.003747) with: {'activation': 'relu', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 100}
# 0.980016 (0.002806) with: {'activation': 'relu', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 300}
# 0.980016 (0.002806) with: {'activation': 'relu', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 600}
# 0.980016 (0.002806) with: {'activation': 'relu', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.3, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.3, 'max_iter': 50}
# 0.980016 (0.002806) with: {'activation': 'relu', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.3, 'max_iter': 100}
# 0.978020 (0.005629) with: {'activation': 'relu', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.3, 'max_iter': 300}
# 0.978020 (0.005629) with: {'activation': 'relu', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.3, 'max_iter': 600}
# 0.978020 (0.005629) with: {'activation': 'relu', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.3, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.4, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.4, 'max_iter': 50}
# 0.977353 (0.005221) with: {'activation': 'relu', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.4, 'max_iter': 100}
# 0.978019 (0.004295) with: {'activation': 'relu', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.4, 'max_iter': 300}
# 0.978019 (0.004295) with: {'activation': 'relu', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.4, 'max_iter': 600}
# 0.978019 (0.004295) with: {'activation': 'relu', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.4, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.1, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.1, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.1, 'max_iter': 100}
# 0.980681 (0.001865) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.1, 'max_iter': 300}
# 0.980681 (0.001865) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.1, 'max_iter': 600}
# 0.980681 (0.001865) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.1, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.2, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.2, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.2, 'max_iter': 100}
# 0.980681 (0.001865) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.2, 'max_iter': 300}
# 0.980681 (0.001865) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.2, 'max_iter': 600}
# 0.980681 (0.001865) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.2, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.3, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.3, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.3, 'max_iter': 100}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.3, 'max_iter': 300}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.3, 'max_iter': 600}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.3, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.4, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.4, 'max_iter': 50}
# 0.978685 (0.004688) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.4, 'max_iter': 100}
# 0.978020 (0.005629) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.4, 'max_iter': 300}
# 0.978020 (0.005629) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.4, 'max_iter': 600}
# 0.978020 (0.005629) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.4, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.1, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.1, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.1, 'max_iter': 100}
# 0.980681 (0.001865) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.1, 'max_iter': 300}
# 0.980681 (0.001865) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.1, 'max_iter': 600}
# 0.980681 (0.001865) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.1, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.2, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.2, 'max_iter': 50}
# 0.980681 (0.001865) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.2, 'max_iter': 100}
# 0.980681 (0.001865) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.2, 'max_iter': 300}
# 0.980681 (0.001865) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.2, 'max_iter': 600}
# 0.980681 (0.001865) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.2, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.3, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.3, 'max_iter': 50}
# 0.980016 (0.002806) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.3, 'max_iter': 100}
# 0.980016 (0.002806) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.3, 'max_iter': 300}
# 0.980016 (0.002806) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.3, 'max_iter': 600}
# 0.980016 (0.002806) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.3, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.4, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.4, 'max_iter': 50}
# 0.980016 (0.002806) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.4, 'max_iter': 100}
# 0.980016 (0.002806) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.4, 'max_iter': 300}
# 0.980016 (0.002806) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.4, 'max_iter': 600}
# 0.980016 (0.002806) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.4, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.1, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.1, 'max_iter': 50}
# 0.980681 (0.001865) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.1, 'max_iter': 100}
# 0.980016 (0.002806) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.1, 'max_iter': 300}
# 0.980016 (0.002806) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.1, 'max_iter': 600}
# 0.980016 (0.002806) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.1, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.2, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.2, 'max_iter': 50}
# 0.980016 (0.002806) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.2, 'max_iter': 100}
# 0.980016 (0.002806) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.2, 'max_iter': 300}
# 0.980016 (0.002806) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.2, 'max_iter': 600}
# 0.980016 (0.002806) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.2, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.3, 'max_iter': 10}
# 0.980681 (0.001865) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.3, 'max_iter': 50}
# 0.980016 (0.002806) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.3, 'max_iter': 100}
# 0.980016 (0.002806) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.3, 'max_iter': 300}
# 0.980016 (0.002806) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.3, 'max_iter': 600}
# 0.980016 (0.002806) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.3, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.4, 'max_iter': 10}
# 0.980015 (0.001615) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.4, 'max_iter': 50}
# 0.980016 (0.002806) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.4, 'max_iter': 100}
# 0.980016 (0.002806) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.4, 'max_iter': 300}
# 0.980016 (0.002806) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.4, 'max_iter': 600}
# 0.980016 (0.002806) with: {'activation': 'relu', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.4, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.1, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.1, 'max_iter': 50}
# 0.980681 (0.001865) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.1, 'max_iter': 100}
# 0.980681 (0.001865) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.1, 'max_iter': 300}
# 0.980681 (0.001865) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.1, 'max_iter': 600}
# 0.980681 (0.001865) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.1, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.2, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.2, 'max_iter': 50}
# 0.980681 (0.001865) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.2, 'max_iter': 100}
# 0.980681 (0.001865) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.2, 'max_iter': 300}
# 0.980681 (0.001865) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.2, 'max_iter': 600}
# 0.980681 (0.001865) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.2, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.3, 'max_iter': 10}
# 0.980681 (0.001865) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.3, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.3, 'max_iter': 100}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.3, 'max_iter': 300}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.3, 'max_iter': 600}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.3, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.4, 'max_iter': 10}
# 0.980681 (0.001865) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.4, 'max_iter': 50}
# 0.979351 (0.003747) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.4, 'max_iter': 100}
# 0.979351 (0.003747) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.4, 'max_iter': 300}
# 0.979351 (0.003747) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.4, 'max_iter': 600}
# 0.979351 (0.003747) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.4, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 100}
# 0.980681 (0.001865) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 300}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 600}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 50}
# 0.980681 (0.001865) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 100}
# 0.978685 (0.004688) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 300}
# 0.978685 (0.004688) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 600}
# 0.978685 (0.004688) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.3, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.3, 'max_iter': 50}
# 0.981348 (0.002475) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.3, 'max_iter': 100}
# 0.979352 (0.005223) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.3, 'max_iter': 300}
# 0.979352 (0.005223) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.3, 'max_iter': 600}
# 0.979352 (0.005223) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.3, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.4, 'max_iter': 10}
# 0.980016 (0.002806) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.4, 'max_iter': 50}
# 0.980015 (0.001615) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.4, 'max_iter': 100}
# 0.979349 (0.002473) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.4, 'max_iter': 300}
# 0.979349 (0.002473) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.4, 'max_iter': 600}
# 0.979349 (0.002473) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.4, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.1, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.1, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.1, 'max_iter': 100}
# 0.976689 (0.007510) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.1, 'max_iter': 300}
# 0.974693 (0.010333) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.1, 'max_iter': 600}
# 0.974693 (0.010333) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.1, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.2, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.2, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.2, 'max_iter': 100}
# 0.978685 (0.004688) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.2, 'max_iter': 300}
# 0.978685 (0.004688) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.2, 'max_iter': 600}
# 0.978685 (0.004688) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.2, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.3, 'max_iter': 10}
# 0.980680 (0.000934) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.3, 'max_iter': 50}
# 0.979349 (0.002473) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.3, 'max_iter': 100}
# 0.978684 (0.003376) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.3, 'max_iter': 300}
# 0.978684 (0.003376) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.3, 'max_iter': 600}
# 0.978684 (0.003376) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.3, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.4, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.4, 'max_iter': 50}
# 0.979351 (0.003747) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.4, 'max_iter': 100}
# 0.980681 (0.001865) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.4, 'max_iter': 300}
# 0.980681 (0.001865) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.4, 'max_iter': 600}
# 0.980681 (0.001865) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.4, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.1, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.1, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.1, 'max_iter': 100}
# 0.978685 (0.004688) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.1, 'max_iter': 300}
# 0.978020 (0.005629) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.1, 'max_iter': 600}
# 0.978020 (0.005629) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.1, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.2, 'max_iter': 10}
# 0.979347 (0.002498) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.2, 'max_iter': 50}
# 0.978680 (0.003405) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.2, 'max_iter': 100}
# 0.976019 (0.004303) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.2, 'max_iter': 300}
# 0.976019 (0.004303) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.2, 'max_iter': 600}
# 0.976019 (0.004303) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.2, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.3, 'max_iter': 10}
# 0.978680 (0.003405) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.3, 'max_iter': 50}
# 0.977349 (0.003393) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.3, 'max_iter': 100}
# 0.976017 (0.004313) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.3, 'max_iter': 300}
# 0.976017 (0.004313) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.3, 'max_iter': 600}
# 0.976017 (0.004313) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.3, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.4, 'max_iter': 10}
# 0.977347 (0.005256) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.4, 'max_iter': 50}
# 0.973351 (0.002499) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.4, 'max_iter': 100}
# 0.973351 (0.002499) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.4, 'max_iter': 300}
# 0.973351 (0.002499) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.4, 'max_iter': 600}
# 0.973351 (0.002499) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.4, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.1, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.1, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.1, 'max_iter': 100}
# 0.976024 (0.008451) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.1, 'max_iter': 300}
# 0.976024 (0.008451) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.1, 'max_iter': 600}
# 0.976024 (0.008451) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.1, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.2, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.2, 'max_iter': 50}
# 0.979351 (0.003747) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.2, 'max_iter': 100}
# 0.974693 (0.010333) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.2, 'max_iter': 300}
# 0.974693 (0.010333) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.2, 'max_iter': 600}
# 0.974693 (0.010333) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.2, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.3, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.3, 'max_iter': 50}
# 0.976024 (0.008451) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.3, 'max_iter': 100}
# 0.976024 (0.008451) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.3, 'max_iter': 300}
# 0.976024 (0.008451) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.3, 'max_iter': 600}
# 0.976024 (0.008451) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.3, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.4, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.4, 'max_iter': 50}
# 0.976689 (0.007510) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.4, 'max_iter': 100}
# 0.976689 (0.007510) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.4, 'max_iter': 300}
# 0.976689 (0.007510) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.4, 'max_iter': 600}
# 0.976689 (0.007510) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.4, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.1, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.1, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.1, 'max_iter': 100}
# 0.978685 (0.004688) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.1, 'max_iter': 300}
# 0.978685 (0.004688) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.1, 'max_iter': 600}
# 0.978685 (0.004688) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.1, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.2, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.2, 'max_iter': 50}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.2, 'max_iter': 100}
# 0.979351 (0.003747) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.2, 'max_iter': 300}
# 0.979351 (0.003747) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.2, 'max_iter': 600}
# 0.979351 (0.003747) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.2, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.3, 'max_iter': 10}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.3, 'max_iter': 50}
# 0.978684 (0.003376) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.3, 'max_iter': 100}
# 0.978684 (0.003376) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.3, 'max_iter': 300}
# 0.978684 (0.003376) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.3, 'max_iter': 600}
# 0.978684 (0.003376) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.3, 'max_iter': 1000}
# 0.981347 (0.000924) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.4, 'max_iter': 10}
# 0.980681 (0.001865) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.4, 'max_iter': 50}
# 0.978017 (0.003245) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.4, 'max_iter': 100}
# 0.978017 (0.003245) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.4, 'max_iter': 300}
# 0.978017 (0.003245) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.4, 'max_iter': 600}
# 0.978017 (0.003245) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.4, 'max_iter': 1000}
# Amphet
# Best: 0.671560 using {'activation': 'logistic', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.3, 'max_iter': 50}
# 0.581572 (0.051826) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 10}
# 0.660226 (0.000320) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 50}
# 0.660226 (0.000320) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 100}
# 0.659561 (0.000621) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 300}
# 0.659561 (0.000621) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 600}
# 0.659561 (0.000621) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 1000}
# 0.628893 (0.033850) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 10}
# 0.668226 (0.012615) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 50}
# 0.666230 (0.014044) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 100}
# 0.665565 (0.014611) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 300}
# 0.665565 (0.014611) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 600}
# 0.665565 (0.014611) with: {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 1000}
# ...
# 0.596935 (0.061237) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.4, 'max_iter': 100}
# 0.596935 (0.061237) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.4, 'max_iter': 300}
# 0.596935 (0.061237) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.4, 'max_iter': 600}
# 0.596935 (0.061237) with: {'activation': 'relu', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.4, 'max_iter': 1000}
# 0.671556 (0.021509) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 10}
# 0.665556 (0.012273) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 50}
# 0.656906 (0.016764) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 100}
# 0.636946 (0.041522) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 300}
# 0.635615 (0.043323) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 600}
# 0.633619 (0.046038) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.1, 'max_iter': 1000}
# 0.657550 (0.049668) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 10}
# 0.673587 (0.039457) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 50}
# 0.663607 (0.053389) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 100}
# 0.667599 (0.047804) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 300}
# 0.666269 (0.049664) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 600}
# 0.666269 (0.049664) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 1000}
# 0.620218 (0.085238) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.3, 'max_iter': 10}
# 0.623621 (0.040611) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.3, 'max_iter': 50}
# 0.626282 (0.037040) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.3, 'max_iter': 100}
# 0.624951 (0.038821) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.3, 'max_iter': 300}
# 0.624951 (0.038821) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.3, 'max_iter': 600}
# 0.624951 (0.038821) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.3, 'max_iter': 1000}
# 0.584886 (0.061437) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.4, 'max_iter': 10}
# 0.629605 (0.027799) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.4, 'max_iter': 50}
# 0.632266 (0.024313) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.4, 'max_iter': 100}
# 0.636258 (0.019281) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.4, 'max_iter': 300}
# 0.636258 (0.019281) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.4, 'max_iter': 600}
# 0.636258 (0.019281) with: {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.4, 'max_iter': 1000}
# 0.659553 (0.011329) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.1, 'max_iter': 10}
# 0.650888 (0.026089) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.1, 'max_iter': 50}
# 0.637581 (0.023701) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.1, 'max_iter': 100}
# 0.628266 (0.029998) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.1, 'max_iter': 300}
# 0.628931 (0.029398) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.1, 'max_iter': 600}
# 0.628931 (0.029398) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.1, 'max_iter': 1000}
# 0.666890 (0.014781) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.2, 'max_iter': 10}
# 0.636242 (0.037560) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.2, 'max_iter': 50}
# 0.612290 (0.050349) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.2, 'max_iter': 100}
# 0.618278 (0.045153) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.2, 'max_iter': 300}
# 0.618278 (0.045153) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.2, 'max_iter': 600}
# 0.618278 (0.045153) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.2, 'max_iter': 1000}
# 0.606904 (0.052966) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.3, 'max_iter': 10}
# 0.622917 (0.001297) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.3, 'max_iter': 50}
# 0.617594 (0.006231) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.3, 'max_iter': 100}
# 0.614267 (0.010935) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.3, 'max_iter': 300}
# 0.614267 (0.010935) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.3, 'max_iter': 600}
# 0.614267 (0.010935) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.3, 'max_iter': 1000}
# 0.622905 (0.022141) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.4, 'max_iter': 10}
# 0.584261 (0.030011) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.4, 'max_iter': 50}
# 0.572285 (0.024498) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.4, 'max_iter': 100}
# 0.572950 (0.024532) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.4, 'max_iter': 300}
# 0.572950 (0.024532) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.4, 'max_iter': 600}
# 0.572950 (0.024532) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.4, 'max_iter': 1000}
# 0.593549 (0.060194) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.1, 'max_iter': 10}
# 0.554225 (0.181888) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.1, 'max_iter': 50}
# 0.535595 (0.172443) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.1, 'max_iter': 100}
# 0.538922 (0.173875) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.1, 'max_iter': 300}
# 0.538922 (0.173875) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.1, 'max_iter': 600}
# 0.538922 (0.173875) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.1, 'max_iter': 1000}
# 0.494888 (0.123408) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.2, 'max_iter': 10}
# 0.551574 (0.132746) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.2, 'max_iter': 50}
# 0.533610 (0.123027) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.2, 'max_iter': 100}
# 0.534275 (0.123308) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.2, 'max_iter': 300}
# 0.534275 (0.123308) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.2, 'max_iter': 600}
# 0.534275 (0.123308) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.2, 'max_iter': 1000}
# 0.448886 (0.156893) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.3, 'max_iter': 10}
# 0.484930 (0.086810) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.3, 'max_iter': 50}
# 0.486926 (0.089568) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.3, 'max_iter': 100}
# 0.488922 (0.092330) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.3, 'max_iter': 300}
# 0.488922 (0.092330) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.3, 'max_iter': 600}
# 0.488922 (0.092330) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.3, 'max_iter': 1000}
# 0.604214 (0.053689) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.4, 'max_iter': 10}
# 0.570254 (0.059804) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.4, 'max_iter': 50}
# 0.562935 (0.054531) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.4, 'max_iter': 100}
# 0.561605 (0.053731) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.4, 'max_iter': 300}
# 0.561605 (0.053731) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.4, 'max_iter': 600}
# 0.561605 (0.053731) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.4, 'max_iter': 1000}
# 0.630888 (0.030487) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.1, 'max_iter': 10}
# 0.651554 (0.016094) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.1, 'max_iter': 50}
# 0.639578 (0.011666) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.1, 'max_iter': 100}
# 0.629598 (0.021723) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.1, 'max_iter': 300}
# 0.628933 (0.022549) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.1, 'max_iter': 600}
# 0.628933 (0.022549) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.1, 'max_iter': 1000}
# 0.580886 (0.063500) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.2, 'max_iter': 10}
# 0.554908 (0.147182) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.2, 'max_iter': 50}
# 0.544262 (0.141791) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.2, 'max_iter': 100}
# 0.535613 (0.138465) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.2, 'max_iter': 300}
# 0.535613 (0.138465) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.2, 'max_iter': 600}
# 0.535613 (0.138465) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.2, 'max_iter': 1000}
# 0.578890 (0.060744) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.3, 'max_iter': 10}
# 0.534917 (0.085450) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.3, 'max_iter': 50}
# 0.528929 (0.079357) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.3, 'max_iter': 100}
# 0.520945 (0.071985) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.3, 'max_iter': 300}
# 0.520945 (0.071985) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.3, 'max_iter': 600}
# 0.520945 (0.071985) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.3, 'max_iter': 1000}
# 0.586889 (0.103995) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.4, 'max_iter': 10}
# 0.606900 (0.064290) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.4, 'max_iter': 50}
# 0.600246 (0.060323) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.4, 'max_iter': 100}
# 0.600246 (0.060323) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.4, 'max_iter': 300}
# 0.600246 (0.060323) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.4, 'max_iter': 600}
# 0.600246 (0.060323) with: {'activation': 'tanh', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.4, 'max_iter': 1000}
# 0.680885 (0.010702) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.1, 'max_iter': 10}
# 0.640896 (0.049450) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.1, 'max_iter': 50}
# 0.634908 (0.048249) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.1, 'max_iter': 100}
# 0.619605 (0.051764) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.1, 'max_iter': 300}
# 0.619605 (0.051764) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.1, 'max_iter': 600}
# 0.619605 (0.051764) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.1, 'max_iter': 1000}
# 0.677552 (0.008869) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.2, 'max_iter': 10}
# 0.668897 (0.010045) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.2, 'max_iter': 50}
# 0.652263 (0.033569) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.2, 'max_iter': 100}
# 0.650933 (0.035450) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.2, 'max_iter': 300}
# 0.650933 (0.035450) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.2, 'max_iter': 600}
# 0.650933 (0.035450) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.2, 'max_iter': 1000}
# 0.608889 (0.094233) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.3, 'max_iter': 10}
# 0.604918 (0.058530) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.3, 'max_iter': 50}
# 0.598265 (0.057244) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.3, 'max_iter': 100}
# 0.596269 (0.057156) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.3, 'max_iter': 300}
# 0.596269 (0.057156) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.3, 'max_iter': 600}
# 0.596269 (0.057156) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.3, 'max_iter': 1000}
# 0.649552 (0.017594) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.4, 'max_iter': 10}
# 0.622913 (0.006051) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.4, 'max_iter': 50}
# 0.612933 (0.008923) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.4, 'max_iter': 100}
# 0.612933 (0.008923) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.4, 'max_iter': 300}
# 0.612933 (0.008923) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.4, 'max_iter': 600}
# 0.612933 (0.008923) with: {'activation': 'tanh', 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.4, 'max_iter': 1000}
# C:\Users\lehuu\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
for params in model_params:
    print(params)
# Out:
# {'activation': 'tanh', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.3, 'max_iter': 100}
# {'activation': 'logistic', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.3, 'max_iter': 50}
# {'activation': 'logistic', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.4, 'max_iter': 50}
# {'activation': 'logistic', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.2, 'max_iter': 300}
# {'activation': 'logistic', 'hidden_layer_sizes': (24, 12), 'learning_rate_init': 0.2, 'max_iter': 50}
# {'activation': 'relu', 'hidden_layer_sizes': (32, 16), 'learning_rate_init': 0.2, 'max_iter': 10}
# {'activation': 'relu', 'hidden_layer_sizes': (64, 32), 'learning_rate_init': 0.1, 'max_iter': 50}
# {'activation': 'relu', 'hidden_layer_sizes': (32, 16, 8), 'learning_rate_init': 0.1, 'max_iter': 10}

# %% [markdown]
# ***USE THESE MODELS***

# %%
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import mean_squared_error, precision_score, recall_score, confusion_matrix


models = [None] * len(y_cols) #list of models in y_cols order
conf_matrices = []  # List of of confusion matrices, one for each substance

#pass inputs X and target y with hyperparams hidden_layer_sizes and learning_rate_init
#returns trained model
def train(X, y, max_iter, hidden_layer_sizes, learning_rate_init, activation):
    X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=1, test_size=0.2)

    clf = MLPClassifier(hidden_layer_sizes=hidden_layer_sizes, learning_rate_init = learning_rate_init, activation=activation, solver = 'sgd', max_iter = max_iter, random_state=1)

    clf.fit(X_train, y_train)
    
    y_pred = clf.predict(X_test) 

    #accuracy and MSE
    print('\nModel Accuracy:', clf.score(X_test, y_test))
    print('Model MSE:', mean_squared_error(y_test, y_pred))
    print('Model Precision:', precision_score(y_test, y_pred, average='micro'))
    print('Model Recall:', recall_score(y_test, y_pred, average='micro'), '\n')
    
    return clf, confusion_matrix(y_test, y_pred)

for drug, params in zip(y_cols, model_params):
    print(drug)
    #use parameters from gridsearch to train models
    models[y_enum[drug].value], c_f = train(X, y[drug], params['max_iter'], params['hidden_layer_sizes'], params['learning_rate_init'], params['activation'])
    conf_matrices.append(c_f)
# Out:
# Alcohol
# C:\Users\lehuu\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Model Accuracy: 0.9867021276595744
# Model MSE: 0.013297872340425532
# Model Precision: 0.9867021276595744
# Model Recall: 0.9867021276595744
#
# Amphet
#
# Model Accuracy: 0.6622340425531915
# Model MSE: 0.3377659574468085
# Model Precision: 0.6622340425531915
# Model Recall: 0.6622340425531915
#
# Cannabis
#
# Model Accuracy: 0.8351063829787234
# Model MSE: 0.16489361702127658
# Model Precision: 0.8351063829787234
# Model Recall: 0.8351063829787234
#
# Coke
#
# Model Accuracy: 0.6223404255319149
# Model MSE: 0.3776595744680851
# Model Precision: 0.6223404255319149
# Model Recall: 0.6223404255319149
#
# Ecstasy
#
# Model Accuracy: 0.6781914893617021
# Model MSE: 0.32180851063829785
# Model Precision: 0.6781914893617021
# Model Recall: 0.6781914893617021
#
# LSD
# C:\Users\lehuu\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Model Accuracy: 0.7074468085106383
# Model MSE: 0.2925531914893617
# Model Precision: 0.7074468085106383
# Model Recall: 0.7074468085106383
#
# Meth
#
# Model Accuracy: 0.7287234042553191
# Model MSE: 0.2712765957446808
# Model Precision: 0.7287234042553191
# Model Recall: 0.7287234042553191
#
# Mushrooms
#
# Model Accuracy: 0.7074468085106383
# Model MSE: 0.2925531914893617
# Model Precision: 0.7074468085106383
# Model Recall: 0.7074468085106383
# C:\Users\lehuu\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\lehuu\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
for i, m in enumerate(conf_matrices):
    fig, ax = plt.subplots(figsize=(8,8))
    fig = sns.heatmap(m, annot=True, cmap="Blues", fmt='g', ax=ax)
    fig.set_title(y_cols[i])
    fig.set_ylabel("True Label")
    fig.set_yticklabels(["0", "1"])
    fig.set_xlabel("Pred Label")
    fig.set_xticklabels(["0", "1"])

# %%
from joblib import dump, load
names = list(range(1, 9))

for model, name in zip(models, names):
    dump(model,'./personalityModels/PersonalityModel'+str(name)+'.joblib')
